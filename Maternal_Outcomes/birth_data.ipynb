# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
#birth_data = pd.read_csv (r'Natality_2016_2021.txt')
#birth_data.to_csv (r'Nat20_21US.csv', index=None)

# %%
birth_data = pd.read_csv('Nat20_21US.csv')
birth_data.head(5)
# Out:
#   Notes\t"State of Residence"\t"State of Residence Code"\t"County of Residence"\t"County of Residence Code"\t"Mother's Pre-pregnancy BMI"\t"Mother's Pre-pregnancy BMI Code"\t"Pre-pregnancy Hypertension"\t"Pre-pregnancy Hypertension Code"\t"Year"\t"Year Code"\tBirths
# 0   AL"\t"01003"\t"Underweight <18.5"\t"1"\t"No"\...
# 1   AL"\t"01003"\t"Underweight <18.5"\t"1"\t"No"\...
# 2   AL"\t"01003"\t"Normal 18.5-24.9"\t"2"\t"No"\t...
# 3   AL"\t"01003"\t"Normal 18.5-24.9"\t"2"\t"No"\t...
# 4   AL"\t"01003"\t"Overweight 25.0-29.9"\t"3"\t"N...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37956\105473876.py in <module>
# ----> 1 birth_data.head(5)
#
# NameError: name 'birth_data' is not defined

# %%
df = pd.read_csv("Natality_2016_2021.txt", sep = " ")
df.head()
# Out:
#                  Notes\t"State       of          Residence"\t"State  \
# 0  \t"Alabama"\t"01"\t"Baldwin  County,  AL"\t"01003"\t"Underweight
# 1  \t"Alabama"\t"01"\t"Baldwin  County,  AL"\t"01003"\t"Underweight
# 2  \t"Alabama"\t"01"\t"Baldwin  County,       AL"\t"01003"\t"Normal
# 3  \t"Alabama"\t"01"\t"Baldwin  County,       AL"\t"01003"\t"Normal
# 4  \t"Alabama"\t"01"\t"Baldwin  County,   AL"\t"01003"\t"Overweight
#
#                                               of.1 Residence Code"\t"County  \
# 0       <18.5"\t"1"\t"No"\t"2"\t"2020"\t"2020"\t11       NaN            NaN
# 1       <18.5"\t"1"\t"No"\t"2"\t"2021"\t"2021"\t17       NaN            NaN
# 2  18.5-24.9"\t"2"\t"No"\t"2"\t"2020"\t"2020"\t133       NaN            NaN
# 3  18.5-24.9"\t"2"\t"No"\t"2"\t"2021"\t"2021"\t149       NaN            NaN
# 4   25.0-29.9"\t"3"\t"No"\t"2"\t"2020"\t"2020"\t67       NaN            NaN
#
#   of.2  Residence"\t"County  of.3  Residence.1  Code"\t"Mother's  \
# 0  NaN                  NaN   NaN          NaN               NaN
# 1  NaN                  NaN   NaN          NaN               NaN
# 2  NaN                  NaN   NaN          NaN               NaN
# 3  NaN                  NaN   NaN          NaN               NaN
# 4  NaN                  NaN   NaN          NaN               NaN
#
#    Pre-pregnancy  BMI"\t"Mother's  Pre-pregnancy.1  BMI  \
# 0            NaN              NaN              NaN  NaN
# 1            NaN              NaN              NaN  NaN
# 2            NaN              NaN              NaN  NaN
# 3            NaN              NaN              NaN  NaN
# 4            NaN              NaN              NaN  NaN
#
#    Code"\t"Pre-pregnancy  Hypertension"\t"Pre-pregnancy  Hypertension  \
# 0                    NaN                            NaN           NaN
# 1                    NaN                            NaN           NaN
# 2                    NaN                            NaN           NaN
# 3                    NaN                            NaN           NaN
# 4                    NaN                            NaN           NaN
#
#    Code"\t"Year"\t"Year  Code"\tBirths
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
